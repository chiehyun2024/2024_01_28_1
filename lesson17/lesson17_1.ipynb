# %%
#使用pandas過濾下載的資料
#下載資料

import requests
from requests import Response
youbike_url = 'https://tcgbusfs.blob.core.windows.net/dotapp/youbike/v2/youbike_immediate.json'
try:
    response:Response = requests.get(youbike_url)
except:
    print("Internet有問題")
else:
    print("連線沒有問題")

if response.status_code == 200:
    print("資料下載成功")
else:
    print("資料下載有問題")
# Out:
# 連線沒有問題
# 資料下載成功

# %%
#取出python的基本資料類型

data:list[dict] = response.json()
data

# %%
import pandas as pd 

df1 = pd.DataFrame(data)
df1
# Out:
#             sno                       sna  ...             infoTime    infoDate
# 0     500101001        YouBike2.0_捷運科技大樓站  ...  2024-03-31 10:43:18  2024-03-31
# 1     500101002    YouBike2.0_復興南路二段273號前  ...  2024-03-31 10:45:18  2024-03-31
# 2     500101003      YouBike2.0_國北教大實小東側門  ...  2024-03-31 10:33:18  2024-03-31
# 3     500101004         YouBike2.0_和平公園東側  ...  2024-03-31 10:44:18  2024-03-31
# 4     500101005      YouBike2.0_辛亥復興路口西北側  ...  2024-03-31 10:44:18  2024-03-31
# ...         ...                       ...  ...                  ...         ...
# 1383  500119087      YouBike2.0_臺大總圖書館西南側  ...  2024-03-31 10:39:18  2024-03-31
# 1384  500119088        YouBike2.0_臺大黑森林西側  ...  2024-03-31 10:44:17  2024-03-31
# 1385  500119089        YouBike2.0_臺大獸醫館南側  ...  2024-03-31 10:40:30  2024-03-31
# 1386  500119090      YouBike2.0_臺大新體育館東南側  ...  2024-03-31 10:42:17  2024-03-31
# 1387  500119091  YouBike2.0_臺大明達館北側(員工宿舍)  ...  2024-03-31 09:42:14  2024-03-31
#
# [1388 rows x 18 columns]

# %%
#使用columns,過濾要使用的欄位
df1 = pd.DataFrame(data,columns=['sna','sarea','ar','tot','sbi','bemp','mday'])
df1
# Out:
#                            sna   sarea  ... bemp                 mday
# 0           YouBike2.0_捷運科技大樓站     大安區  ...   24  2024-03-31 10:43:18
# 1       YouBike2.0_復興南路二段273號前     大安區  ...   16  2024-03-31 10:45:18
# 2         YouBike2.0_國北教大實小東側門     大安區  ...    9  2024-03-31 10:33:18
# 3            YouBike2.0_和平公園東側     大安區  ...    9  2024-03-31 10:44:18
# 4         YouBike2.0_辛亥復興路口西北側     大安區  ...    3  2024-03-31 10:44:18
# ...                        ...     ...  ...  ...                  ...
# 1383      YouBike2.0_臺大總圖書館西南側  臺大公館校區  ...   16  2024-03-31 10:39:18
# 1384        YouBike2.0_臺大黑森林西側  臺大公館校區  ...   19  2024-03-31 10:44:17
# 1385        YouBike2.0_臺大獸醫館南側  臺大公館校區  ...   18  2024-03-31 10:40:30
# 1386      YouBike2.0_臺大新體育館東南側  臺大公館校區  ...   26  2024-03-31 10:42:17
# 1387  YouBike2.0_臺大明達館北側(員工宿舍)  臺大公館校區  ...   18  2024-03-31 09:42:14
#
# [1388 rows x 7 columns]

# %%
#更改欄位名稱
df2 = df1.rename(columns={'sna':'站點名稱','sarea':'行政區','ar':'地址','tot':'車輛總數','sbi':'可借','bemp':'可還','mday':'時間'})
df2
# Out:
#                           站點名稱     行政區  ...  可還                   時間
# 0           YouBike2.0_捷運科技大樓站     大安區  ...  24  2024-03-31 10:43:18
# 1       YouBike2.0_復興南路二段273號前     大安區  ...  16  2024-03-31 10:45:18
# 2         YouBike2.0_國北教大實小東側門     大安區  ...   9  2024-03-31 10:33:18
# 3            YouBike2.0_和平公園東側     大安區  ...   9  2024-03-31 10:44:18
# 4         YouBike2.0_辛亥復興路口西北側     大安區  ...   3  2024-03-31 10:44:18
# ...                        ...     ...  ...  ..                  ...
# 1383      YouBike2.0_臺大總圖書館西南側  臺大公館校區  ...  16  2024-03-31 10:39:18
# 1384        YouBike2.0_臺大黑森林西側  臺大公館校區  ...  19  2024-03-31 10:44:17
# 1385        YouBike2.0_臺大獸醫館南側  臺大公館校區  ...  18  2024-03-31 10:40:30
# 1386      YouBike2.0_臺大新體育館東南側  臺大公館校區  ...  26  2024-03-31 10:42:17
# 1387  YouBike2.0_臺大明達館北側(員工宿舍)  臺大公館校區  ...  18  2024-03-31 09:42:14
#
# [1388 rows x 7 columns]

# %%
# 顯示非表格的資訊
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1388 entries, 0 to 1387
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   站點名稱    1388 non-null   object
#  1   行政區     1388 non-null   object
#  2   地址      1388 non-null   object
#  3   車輛總數    1388 non-null   int64
#  4   可借      1388 non-null   int64
#  5   可還      1388 non-null   int64
#  6   時間      1388 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 76.0+ KB
